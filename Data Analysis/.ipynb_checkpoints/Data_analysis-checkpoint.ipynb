# %% [markdown]
# # In this notebook, I'll try to apply some machine learning techniques.

# %% [markdown]
# #### First of all,  I install require packagues for later analysis and I load WHOCOMPLETE dataset from DATASETS directory.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
whodf = pd.read_csv("../DATASETS/whocomplete.csv", sep = ";")
whodf.head(5)
# Out:
#        Country Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan  WestAsia                          151.0
# 1      Albania    Europe                           27.0
# 2      Algeria    Africa                            6.0
# 3      Andorra    Europe                           19.0
# 4       Angola    Africa                          146.0
#
#    Adult literacy rate (%)  \
# 0                    28.00
# 1                    98.70
# 2                    69.90
# 3                    98.75
# 4                    67.40
#
#    Gross national income per capita (PPP international $)  \
# 0                                             9800.0
# 1                                             6000.0
# 2                                             5940.0
# 3                                            15905.0
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                           90.0
# ...

# %%
# FEATURE PREPROCESSING
